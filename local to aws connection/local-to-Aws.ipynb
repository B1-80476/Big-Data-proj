# %%
pip list
# Out:
# Package                   VersionNote: you may need to restart the kernel to use updated packages.
#
# ------------------------- ---------------
# anyio                     4.2.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.14.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.7.0
# boto3                     1.34.93
# botocore                  1.34.93
# certifi                   2024.2.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# click                     8.1.7
# colorama                  0.4.6
# comm                      0.2.1
# contourpy                 1.2.0
# cycler                    0.12.1
# databricks-api            0.9.0
# databricks-cli            0.18.0
# dataclasses               0.6
# ...

# %%
import boto3

# Replace these values with your own access key ID and secret access key
ACCESS_KEY_ID = '******4N6TJ*********'
SECRET_ACCESS_KEY = '**********EGglg*****UpPpz***************'
REGION_NAME = 'ap-south-1'
BUCKET_NAME = 'practice-dbda'

# Create an S3 client
s3 = boto3.client('s3',
                  aws_access_key_id=ACCESS_KEY_ID,
                  aws_secret_access_key=SECRET_ACCESS_KEY,
                  region_name=REGION_NAME)

# Specify the local path to your CV file
local_file_path = 'C:/Users/admin/Desktop/ML project/job_skills.csv'

# Specify the key (file name) under which to store the CV file in the bucket
key = 'job_skills.csv'

# Upload the CV file to the S3 bucket
s3.upload_file(local_file_path, BUCKET_NAME, key)

print('CV file uploaded successfully.')
# Out:
# CV file uploaded successfully.
